# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
header = {'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36'}

# %%
def soup_(url):
    page = requests.get(url, headers = header)
    soup = BeautifulSoup(page.content,'html.parser')
    soup.prettify()
    return soup

# %%
soup = soup_("https://www.countryzipcode.com/romania")

# %%
a = soup.find_all('div',{'class':'regions'})
b = a[0].find_all('a')

# %%
links = []
state = []
i = 0
for _ in b:
    st = _.get_text()
    li = _['href']
    state.append(st)
    links.append(li)

links, state
# Out:
# (['https://www.countryzipcode.com/romania/alba',
#   'https://www.countryzipcode.com/romania/arad',
#   'https://www.countryzipcode.com/romania/arges',
#   'https://www.countryzipcode.com/romania/bacau',
#   'https://www.countryzipcode.com/romania/bihor',
#   'https://www.countryzipcode.com/romania/bistrita_nasaud',
#   'https://www.countryzipcode.com/romania/botosani',
#   'https://www.countryzipcode.com/romania/braila',
#   'https://www.countryzipcode.com/romania/brasov',
#   'https://www.countryzipcode.com/romania/bucuresti',
#   'https://www.countryzipcode.com/romania/buzau',
#   'https://www.countryzipcode.com/romania/calarasi_ro',
#   'https://www.countryzipcode.com/romania/caras_severin',
#   'https://www.countryzipcode.com/romania/cluj',
#   'https://www.countryzipcode.com/romania/constanta',
#   'https://www.countryzipcode.com/romania/covasna',
#   'https://www.countryzipcode.com/romania/dambovita',
#   'https://www.countryzipcode.com/romania/dolj',
#   'https://www.countryzipcode.com/romania/galati',
#   'https://www.countryzipcode.com/romania/giurgiu',
#   'https://www.countryzipcode.com/romania/gorj',
#   'https://www.countryzipcode.com/romania/harghita',
#   'https://www.countryzipcode.com/romania/hunedoara',
#   'https://www.countryzipcode.com/romania/ialomita',
#   'https://www.countryzipcode.com/romania/iasi',
#   'https://www.countryzipcode.com/romania/ilfov',
#   'https://www.countryzipcode.com/romania/maramures',
#   'https://www.countryzipcode.com/romania/mehedinti',
#   'https://www.countryzipcode.com/romania/mures',
#   'https://www.countryzipcode.com/romania/neamt',
#   'https://www.countryzipcode.com/romania/olt_county',
#   'https://www.countryzipcode.com/romania/prahova',
#   'https://www.countryzipcode.com/romania/salaj',
#   'https://www.countryzipcode.com/romania/satu_mare',
#   'https://www.countryzipcode.com/romania/sibiu',
#   'https://www.countryzipcode.com/romania/suceava',
#   'https://www.countryzipcode.com/romania/teleorman',
#   'https://www.countryzipcode.com/romania/timis',
#   'https://www.countryzipcode.com/romania/tulcea',
#   'https://www.countryzipcode.com/romania/valcea',
#   'https://www.countryzipcode.com/romania/vaslui',
#   'https://www.countryzipcode.com/romania/vrancea'],
#  ['Alba',
#   'Arad',
#   'Arges',
#   'Bacau',
#   'Bihor',
#   'Bistrita-Nasaud',
#   'Botosani',
#   'Braila',
#   'Brasov',
#   'Bucuresti',
#   'Buzau',
#   'Calarasi',
#   'Caras-Severin',
#   'Cluj',
#   'Constanta',
#   'Covasna',
#   'Dambovita',
#   'Dolj',
#   'Galati',
#   'Giurgiu',
#   'Gorj',
#   'Harghita',
#   'Hunedoara',
#   'Ialomita',
#   'Iasi',
#   'Ilfov',
#   'Maramures',
#   'Mehedinti',
#   'Mures',
#   'Neamt',
#   'Olt County',
#   'Prahova',
#   'Salaj',
#   'Satu Mare',
#   'Sibiu',
#   'Suceava',
#   'Teleorman',
#   'Timis',
#   'Tulcea',
#   'Valcea',
#   'Vaslui',
#   'Vrancea'])

# %%
zipcode = []
states = []
city = []
for i in range(len(links)):
    soup = soup_(links[i])
    a = soup.find_all('div',{'class':'regions'})
    b = a[0].find_all('a')
    for _ in b:
        st = _.get_text()
        data = st.split(' - ')
        zipcode.append(data[0])
        city.append(data[1])
        states.append(state[i])

# %%
df = pd.DataFrame({
    'state': states,
    'city': city,
    'zipcode': zipcode
})
df.set_index('state', inplace = True)
df.sort_index(inplace = True)
df.drop_duplicates(keep="first", inplace = True)
df
# Out:
#                city zipcode
# state
# Alba       Barabant  510001
# Alba     Alba Iulia  510002
# Alba        Micesti  510002
# Alba          Oarda  510003
# Alba        Paclisa  510004
# ...             ...     ...
# Vrancea     Vulturu  627455
# Vrancea    Botarlau  627456
# Vrancea  Hangulesti  627457
# Vrancea      Maluri  627458
# Vrancea  Vadu Rosca  627459
#
# [37915 rows x 2 columns]

# %%
df.to_csv("Romania.csv")
