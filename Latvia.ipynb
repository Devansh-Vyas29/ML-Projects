# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
header = {'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36'}

# %%
def soup_(url):
    page = requests.get(url, headers = header)
    soup = BeautifulSoup(page.content,'html.parser')
    soup.prettify()
    return soup

# %%
soup = soup_("https://www.countryzipcode.com/latvia")

# %%
a = soup.find_all('div',{'class':'regions'})

# %%
b = a[0].find_all('a')

# %%
links = []
state = []
for _ in b:
    st = _.get_text()
    li = _['href']
    state.append(st)
    links.append(li)
links, state
# Out:
# (['https://www.countryzipcode.com/latvia/adazu_novads',
#   'https://www.countryzipcode.com/latvia/aglonas_novads',
#   'https://www.countryzipcode.com/latvia/aizkraukles_novads',
#   'https://www.countryzipcode.com/latvia/aizputes_novads',
#   'https://www.countryzipcode.com/latvia/aknistes_novads',
#   'https://www.countryzipcode.com/latvia/alojas_novads',
#   'https://www.countryzipcode.com/latvia/alsungas_novads',
#   'https://www.countryzipcode.com/latvia/aluksnes_novads',
#   'https://www.countryzipcode.com/latvia/amatas_novads',
#   'https://www.countryzipcode.com/latvia/apes_novads',
#   'https://www.countryzipcode.com/latvia/auces_novads',
#   'https://www.countryzipcode.com/latvia/babites_novads',
#   'https://www.countryzipcode.com/latvia/baldones_novads',
#   'https://www.countryzipcode.com/latvia/baltinavas_novads',
#   'https://www.countryzipcode.com/latvia/balvu_novads',
#   'https://www.countryzipcode.com/latvia/bauskas_novads',
#   'https://www.countryzipcode.com/latvia/beverinas_novads',
#   'https://www.countryzipcode.com/latvia/brocenu_novads',
#   'https://www.countryzipcode.com/latvia/burtnieku_novads',
#   'https://www.countryzipcode.com/latvia/carnikavas_novads',
#   'https://www.countryzipcode.com/latvia/cesu_novads',
#   'https://www.countryzipcode.com/latvia/cesvaines_novads',
#   'https://www.countryzipcode.com/latvia/ciblas_novads',
#   'https://www.countryzipcode.com/latvia/dagdas_novads',
#   'https://www.countryzipcode.com/latvia/daugavpils_novads',
#   'https://www.countryzipcode.com/latvia/daugavpils',
#   'https://www.countryzipcode.com/latvia/dobeles_novads',
#   'https://www.countryzipcode.com/latvia/dundagas_novads',
#   'https://www.countryzipcode.com/latvia/durbes_novads',
#   'https://www.countryzipcode.com/latvia/engures_novads',
#   'https://www.countryzipcode.com/latvia/erglu_novads',
#   'https://www.countryzipcode.com/latvia/garkalnes_novads',
#   'https://www.countryzipcode.com/latvia/grobinas_novads',
#   'https://www.countryzipcode.com/latvia/gulbenes_novads',
#   'https://www.countryzipcode.com/latvia/iecavas_novads',
#   'https://www.countryzipcode.com/latvia/ikskiles_novads',
#   'https://www.countryzipcode.com/latvia/ilukstes_novads',
#   'https://www.countryzipcode.com/latvia/incukalna_novads',
#   'https://www.countryzipcode.com/latvia/jaunjelgavas_novads',
#   'https://www.countryzipcode.com/latvia/jaunpiebalgas_novads',
#   'https://www.countryzipcode.com/latvia/jaunpils_novads',
#   'https://www.countryzipcode.com/latvia/jekabpils_novads',
#   'https://www.countryzipcode.com/latvia/jekabpils',
#   'https://www.countryzipcode.com/latvia/jelgava',
#   'https://www.countryzipcode.com/latvia/jelgavas_novads',
#   'https://www.countryzipcode.com/latvia/jurmala',
#   'https://www.countryzipcode.com/latvia/kandavas_novads',
#   'https://www.countryzipcode.com/latvia/karsavas_novads',
#   'https://www.countryzipcode.com/latvia/keguma_novads',
#   'https://www.countryzipcode.com/latvia/kekavas_novads',
#   'https://www.countryzipcode.com/latvia/kocenu_novads',
#   'https://www.countryzipcode.com/latvia/kokneses_novads',
#   'https://www.countryzipcode.com/latvia/kraslavas_novads',
#   'https://www.countryzipcode.com/latvia/krimuldas_novads',
#   'https://www.countryzipcode.com/latvia/krustpils_novads',
#   'https://www.countryzipcode.com/latvia/kuldigas_novads',
#   'https://www.countryzipcode.com/latvia/lielvardes_novads',
#   'https://www.countryzipcode.com/latvia/liepaja',
#   'https://www.countryzipcode.com/latvia/ligatnes_novads',
#   'https://www.countryzipcode.com/latvia/limbazu_novads',
#   'https://www.countryzipcode.com/latvia/livanu_novads',
#   'https://www.countryzipcode.com/latvia/lubanas_novads',
#   'https://www.countryzipcode.com/latvia/ludzas_novads',
#   'https://www.countryzipcode.com/latvia/madonas_novads',
#   'https://www.countryzipcode.com/latvia/malpils_novads',
#   'https://www.countryzipcode.com/latvia/marupes_novads',
#   'https://www.countryzipcode.com/latvia/mazsalacas_novads',
#   'https://www.countryzipcode.com/latvia/mersraga_novads',
#   'https://www.countryzipcode.com/latvia/nauksenu_novads',
#   'https://www.countryzipcode.com/latvia/neretas_novads',
#   'https://www.countryzipcode.com/latvia/nicas_novads',
#   'https://www.countryzipcode.com/latvia/ogres_novads',
#   'https://www.countryzipcode.com/latvia/olaines_novads',
#   'https://www.countryzipcode.com/latvia/ozolnieku_novads',
#   'https://www.countryzipcode.com/latvia/pargaujas_novads',
#   'https://www.countryzipcode.com/latvia/pavilostas_novads',
#   'https://www.countryzipcode.com/latvia/plavinu_novads',
#   'https://www.countryzipcode.com/latvia/preilu_novads',
#   'https://www.countryzipcode.com/latvia/priekules_novads',
#   'https://www.countryzipcode.com/latvia/priekulu_novads',
#   'https://www.countryzipcode.com/latvia/raunas_novads',
#   'https://www.countryzipcode.com/latvia/rezekne',
#   'https://www.countryzipcode.com/latvia/rezeknes_novads',
#   'https://www.countryzipcode.com/latvia/riebinu_novads',
#   'https://www.countryzipcode.com/latvia/riga',
#   'https://www.countryzipcode.com/latvia/rojas_novads',
#   'https://www.countryzipcode.com/latvia/ropazu_novads',
#   'https://www.countryzipcode.com/latvia/rucavas_novads',
#   'https://www.countryzipcode.com/latvia/rugaju_novads',
#   'https://www.countryzipcode.com/latvia/rujienas_novads',
#   'https://www.countryzipcode.com/latvia/rundales_novads',
#   'https://www.countryzipcode.com/latvia/salacgrivas_novads',
#   'https://www.countryzipcode.com/latvia/salas_novads',
#   'https://www.countryzipcode.com/latvia/salaspils_novads',
#   'https://www.countryzipcode.com/latvia/saldus_novads',
#   'https://www.countryzipcode.com/latvia/saulkrastu_novads',
#   'https://www.countryzipcode.com/latvia/sejas_novads',
#   'https://www.countryzipcode.com/latvia/siguldas_novads',
#   'https://www.countryzipcode.com/latvia/skriveru_novads',
#   'https://www.countryzipcode.com/latvia/skrundas_novads',
#   'https://www.countryzipcode.com/latvia/smiltenes_novads',
#   'https://www.countryzipcode.com/latvia/stopinu_novads',
#   'https://www.countryzipcode.com/latvia/strencu_novads',
#   'https://www.countryzipcode.com/latvia/talsu_novads',
#   'https://www.countryzipcode.com/latvia/tervetes_novads',
#   'https://www.countryzipcode.com/latvia/tukuma_novads',
#   'https://www.countryzipcode.com/latvia/vainodes_novads',
#   'https://www.countryzipcode.com/latvia/valkas_novads',
#   'https://www.countryzipcode.com/latvia/valmiera',
#   'https://www.countryzipcode.com/latvia/varaklanu_novads',
#   'https://www.countryzipcode.com/latvia/varkavas_novads',
#   'https://www.countryzipcode.com/latvia/vecpiebalgas_novads',
#   'https://www.countryzipcode.com/latvia/vecumnieku_novads',
#   'https://www.countryzipcode.com/latvia/ventspils_novads',
#   'https://www.countryzipcode.com/latvia/ventspils',
#   'https://www.countryzipcode.com/latvia/viesites_novads',
#   'https://www.countryzipcode.com/latvia/vilakas_novads',
#   'https://www.countryzipcode.com/latvia/vilanu_novads',
#   'https://www.countryzipcode.com/latvia/zilupes_novads'],
#  ['Adazu',
#   'Aglonas',
#   'Aizkraukles',
#   'Aizputes',
#   'Aknistes',
#   'Alojas',
#   'Alsungas',
#   'Aluksnes',
#   'Amatas',
#   'Apes',
#   'Auces',
#   'Babites',
#   'Baldones',
#   'Baltinavas',
#   'Balvu',
#   'Bauskas',
#   'Beverinas',
#   'Brocenu',
#   'Burtnieku',
#   'Carnikavas',
#   'Cesu',
#   'Cesvaines',
#   'Ciblas',
#   'Dagdas',
#   'Daugavpils',
#   'Daugavpils',
#   'Dobeles',
#   'Dundagas',
#   'Durbes',
#   'Engures',
#   'Erglu',
#   'Garkalnes',
#   'Grobinas',
#   'Gulbenes',
#   'Iecavas',
#   'Ikskiles',
#   'Ilukstes',
#   'Incukalna',
#   'Jaunjelgavas',
#   'Jaunpiebalgas',
#   'Jaunpils',
#   'Jekabpils',
#   'Jekabpils',
#   'Jelgava',
#   'Jelgavas',
#   'Jurmala',
#   'Kandavas',
#   'Karsavas',
#   'Keguma',
#   'Kekavas',
#   'Kocenu',
#   'Kokneses',
#   'Kraslavas',
#   'Krimuldas',
#   'Krustpils',
#   'Kuldigas',
#   'Lielvardes',
#   'Liepaja',
#   'Ligatnes',
#   'Limbazu',
#   'Livanu',
#   'Lubanas',
#   'Ludzas',
#   'Madonas',
#   'Malpils',
#   'Marupes',
#   'Mazsalacas',
#   'Mersraga',
#   'Nauksenu',
#   'Neretas',
#   'Nicas',
#   'Ogres',
#   'Olaines',
#   'Ozolnieku',
#   'Pargaujas',
#   'Pavilostas',
#   'Plavinu',
#   'Preilu',
#   'Priekules',
#   'Priekulu',
#   'Raunas',
#   'Rezekne',
#   'Rezeknes',
#   'Riebinu',
#   'Riga',
#   'Rojas',
#   'Ropazu',
#   'Rucavas',
#   'Rugaju',
#   'Rujienas',
#   'Rundales',
#   'Salacgrivas',
#   'Salas',
#   'Salaspils',
#   'Saldus',
#   'Saulkrastu',
#   'Sejas',
#   'Siguldas',
#   'Skriveru',
#   'Skrundas',
#   'Smiltenes',
#   'Stopinu',
#   'Strencu',
#   'Talsu',
#   'Tervetes',
#   'Tukuma',
#   'Vainodes',
#   'Valkas',
#   'Valmiera',
#   'Varaklanu',
#   'Varkavas',
#   'Vecpiebalgas',
#   'Vecumnieku',
#   'Ventspils',
#   'Ventspils',
#   'Viesites',
#   'Vilakas',
#   'Vilanu',
#   'Zilupes'])

# %%
zipcode = []
states = []
city = []
for i in range(len(links)):
    soup = soup_(links[i])
    a = soup.find_all('div',{'class':'regions'})
    b = a[0].find_all('a')
    for _ in b:
        st = _.get_text()
        data = st.split(' - ')
        zipcode.append(data[0])
        city.append(data[1])
        states.append(state[i])

                
[zipcode, states, city]
# Out:
# [['LV-2103',
#   'LV-2103',
#   'LV-2136',
#   'LV-2137',
#   'LV-2137',
#   'LV-2164',
#   'LV-2164',
#   'LV-2164',
#   'LV-2164',
#   'LV-2164',
#   'LV-2164',
#   'LV-2164',
#   'LV-2164',
#   'LV-2164',
#   'LV-2164',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5304',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5653',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5655',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5685',
#   'LV-5687',
#   'LV-5687',
#   'LV-5687',
#   'LV-5687',
#   'LV-5687',
#   'LV-5687',
#   'LV-5101',
#   'LV-5101',
#   'LV-3442',
#   'LV-3443',
#   'LV-3443',
#   'LV-3453',
#   'LV-3453',
#   'LV-3455',
#   'LV-3456',
#   'LV-3456',
#   'LV-3456',
#   'LV-3456',
#   'LV-3456',
#   'LV-3456',
#   'LV-3456',
#   'LV-3457',
#   'LV-5208',
#   'LV-5210',
#   'LV-5210',
#   'LV-5218',
#   'LV-5218',
#   'LV-4043',
#   'LV-4063',
#   'LV-4063',
#   'LV-4063',
#   'LV-4064',
#   'LV-4068',
#   'LV-4068',
#   'LV-3306',
#   'LV-3306',
#   'LV-4301',
#   'LV-4332',
#   'LV-4332',
#   'LV-4333',
#   'LV-4333',
#   'LV-4333',
#   'LV-4335',
#   'LV-4336',
#   'LV-4340',
#   'LV-4341',
#   'LV-4342',
#   'LV-4344',
#   'LV-4345',
#   'LV-4350',
#   'LV-4350',
#   'LV-4351',
#   'LV-4352',
#   'LV-4354',
#   'LV-4358',
#   'LV-4358',
#   'LV-4359',
#   'LV-4101',
#   'LV-4101',
#   'LV-4101',
#   'LV-4101',
#   'LV-4112',
#   'LV-4113',
#   'LV-4113',
#   'LV-4113',
#   'LV-4113',
#   'LV-4139',
#   'LV-4139',
#   'LV-4139',
#   'LV-4139',
#   'LV-4141',
#   'LV-4143',
#   'LV-4143',
#   'LV-4337',
#   'LV-4339',
#   'LV-4348',
#   'LV-4355',
#   'LV-4355',
#   'LV-3708',
#   'LV-3708',
#   'LV-3711',
#   'LV-3711',
#   'LV-3714',
#   'LV-3716',
#   'LV-3721',
#   'LV-3723',
#   'LV-3723',
#   'LV-3723',
#   'LV-3729',
#   'LV-2011',
#   'LV-2011',
#   'LV-2101',
#   'LV-2101',
#   'LV-2101',
#   'LV-2101',
#   'LV-2101',
#   'LV-2105',
#   'LV-2105',
#   'LV-2105',
#   'LV-2105',
#   'LV-2105',
#   'LV-2105',
#   'LV-2105',
#   'LV-2107',
#   'LV-2107',
#   'LV-2107',
#   'LV-2107',
#   'LV-2107',
#   'LV-2107',
#   'LV-2107',
#   'LV-2107',
#   'LV-2107',
#   'LV-2107',
#   'LV-2107',
#   'LV-2107',
#   'LV-2107',
#   'LV-2107',
#   'LV-2107',
#   'LV-2107',
#   'LV-2125',
#   'LV-2125',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4594',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4501',
#   'LV-4561',
#   'LV-4561',
#   'LV-4561',
#   'LV-4561',
#   'LV-4561',
#   'LV-4561',
#   'LV-4561',
#   'LV-4561',
#   'LV-4561',
#   'LV-4561',
#   'LV-4561',
#   'LV-4561',
#   'LV-4561',
#   'LV-4561',
#   'LV-4561',
#   'LV-4561',
#   'LV-4562',
#   'LV-4562',
#   'LV-4562',
#   'LV-4562',
#   'LV-4562',
#   'LV-4562',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4566',
#   'LV-4567',
#   'LV-4567',
#   'LV-4567',
#   'LV-4567',
#   'LV-4567',
#   'LV-4567',
#   'LV-4567',
#   'LV-4567',
#   'LV-4567',
#   'LV-4567',
#   'LV-4567',
#   'LV-4567',
#   'LV-4567',
#   'LV-4567',
#   'LV-4567',
#   'LV-4567',
#   'LV-4570',
#   'LV-4571',
#   'LV-4571',
#   'LV-4571',
#   'LV-4571',
#   'LV-4571',
#   'LV-4571',
#   'LV-4571',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4572',
#   'LV-4573',
#   'LV-4573',
#   'LV-4573',
#   'LV-4573',
#   'LV-4574',
#   'LV-4574',
#   'LV-4574',
#   'LV-4574',
#   'LV-4574',
#   'LV-4574',
#   'LV-4574',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4576',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4580',
#   'LV-4582',
#   'LV-4582',
#   'LV-4582',
#   'LV-4582',
#   'LV-4582',
#   'LV-4582',
#   'LV-4582',
#   'LV-4590',
#   'LV-4590',
#   'LV-4590',
#   'LV-4590',
#   'LV-4590',
#   'LV-4590',
#   'LV-4590',
#   'LV-4590',
#   'LV-4590',
#   'LV-4591',
#   'LV-4591',
#   'LV-4591',
#   'LV-4591',
#   'LV-4591',
#   'LV-4591',
#   'LV-4591',
#   'LV-4591',
#   'LV-4591',
#   'LV-4591',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4592',
#   'LV-4595',
#   'LV-4595',
#   'LV-4595',
#   'LV-4595',
#   'LV-4595',
#   'LV-4595',
#   'LV-4595',
#   'LV-4595',
#   'LV-4595',
#   'LV-4595',
#   'LV-4595',
#   'LV-4595',
#   'LV-4595',
#   'LV-4595',
#   'LV-4595',
#   'LV-3901',
#   'LV-3901',
#   'LV-3901',
#   'LV-3901',
#   'LV-3901',
#   'LV-3901',
#   'LV-3901',
#   'LV-3901',
#   'LV-3907',
#   'LV-3907',
#   'LV-3907',
#   'LV-3907',
#   'LV-3908',
#   'LV-3910',
#   'LV-3910',
#   'LV-3913',
#   'LV-3914',
#   'LV-3914',
#   'LV-3914',
#   'LV-3915',
#   'LV-3918',
#   'LV-3918',
#   'LV-3926',
#   'LV-3926',
#   'LV-3929',
#   'LV-3931',
#   'LV-3931',
#   'LV-3931',
#   'LV-3931',
#   'LV-3931',
#   'LV-3931',
#   'LV-3931',
#   'LV-3931',
#   'LV-3931',
#   'LV-3931',
#   'LV-3932',
#   'LV-3932',
#   'LV-3932',
#   'LV-3936',
#   'LV-3936',
#   'LV-4224',
#   'LV-4224',
#   'LV-4224',
#   'LV-4224',
#   'LV-4245',
#   'LV-4245',
#   'LV-4731',
#   'LV-4731',
#   'LV-3851',
#   'LV-3851',
#   'LV-3851',
#   'LV-3851',
#   'LV-3852',
#   'LV-3852',
#   'LV-3852',
#   'LV-3871',
#   'LV-3873',
#   'LV-3873',
#   'LV-3873',
#   'LV-3873',
#   'LV-4206',
#   'LV-4210',
#   'LV-4211',
#   'LV-4219',
#   'LV-4219',
#   'LV-4219',
#   'LV-4232',
#   'LV-4232',
#   'LV-4712',
#   'LV-4712',
#   'LV-2163',
#   'LV-2163',
#   'LV-2163',
#   'LV-2163',
#   'LV-2163',
#   'LV-2163',
#   'LV-2163',
#   'LV-2163',
#   'LV-2163',
#   'LV-2163',
#   'LV-2163',
#   'LV-4102',
#   'LV-4103',
#   'LV-4136',
#   'LV-4136',
#   'LV-4136',
#   'LV-4136',
#   'LV-4136',
#   'LV-4871',
#   'LV-4871',
#   'LV-4871',
#   'LV-4880',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5706',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5709',
#   'LV-5716',
#   'LV-5716',
#   'LV-5716',
#   'LV-5716',
#   'LV-5716',
#   'LV-5716',
#   'LV-5716',
#   'LV-5716',
#   'LV-5716',
#   'LV-5716',
#   'LV-5716',
#   'LV-5716',
#   'LV-5716',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5719',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5742',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5752',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5674',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5676',
#   'LV-5677',
#   'LV-5677',
#   'LV-5677',
#   'LV-5677',
#   'LV-5677',
#   'LV-5677',
#   'LV-5677',
#   'LV-5677',
#   'LV-5677',
#   'LV-5677',
#   'LV-5677',
#   'LV-5677',
#   'LV-5677',
#   'LV-5677',
#   'LV-5677',
#   'LV-5677',
#   'LV-5677',
#   'LV-5680',
#   'LV-5680',
#   'LV-5680',
#   'LV-5680',
#   'LV-5680',
#   'LV-5680',
#   'LV-5680',
#   'LV-5680',
#   'LV-5680',
#   'LV-5680',
#   'LV-5680',
#   'LV-5680',
#   'LV-5680',
#   'LV-5680',
#   'LV-5680',
#   ...],
#  ['Adazu',
#   'Adazu',
#   'Adazu',
#   'Adazu',
#   'Adazu',
#   'Adazu',
#   'Adazu',
#   'Adazu',
#   'Adazu',
#   'Adazu',
#   'Adazu',
#   'Adazu',
#   'Adazu',
#   'Adazu',
#   'Adazu',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aglonas',
#   'Aizkraukles',
#   'Aizkraukles',
#   'Aizputes',
#   'Aizputes',
#   'Aizputes',
#   'Aizputes',
#   'Aizputes',
#   'Aizputes',
#   'Aizputes',
#   'Aizputes',
#   'Aizputes',
#   'Aizputes',
#   'Aizputes',
#   'Aizputes',
#   'Aizputes',
#   'Aizputes',
#   'Aknistes',
#   'Aknistes',
#   'Aknistes',
#   'Aknistes',
#   'Aknistes',
#   'Alojas',
#   'Alojas',
#   'Alojas',
#   'Alojas',
#   'Alojas',
#   'Alojas',
#   'Alojas',
#   'Alsungas',
#   'Alsungas',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Aluksnes',
#   'Amatas',
#   'Amatas',
#   'Amatas',
#   'Amatas',
#   'Amatas',
#   'Amatas',
#   'Amatas',
#   'Amatas',
#   'Amatas',
#   'Amatas',
#   'Amatas',
#   'Amatas',
#   'Amatas',
#   'Amatas',
#   'Amatas',
#   'Amatas',
#   'Apes',
#   'Apes',
#   'Apes',
#   'Apes',
#   'Apes',
#   'Auces',
#   'Auces',
#   'Auces',
#   'Auces',
#   'Auces',
#   'Auces',
#   'Auces',
#   'Auces',
#   'Auces',
#   'Auces',
#   'Auces',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Babites',
#   'Baldones',
#   'Baldones',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Baltinavas',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Balvu',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Bauskas',
#   'Beverinas',
#   'Beverinas',
#   'Beverinas',
#   'Beverinas',
#   'Beverinas',
#   'Beverinas',
#   'Beverinas',
#   'Beverinas',
#   'Brocenu',
#   'Brocenu',
#   'Brocenu',
#   'Brocenu',
#   'Brocenu',
#   'Brocenu',
#   'Brocenu',
#   'Brocenu',
#   'Brocenu',
#   'Brocenu',
#   'Brocenu',
#   'Brocenu',
#   'Burtnieku',
#   'Burtnieku',
#   'Burtnieku',
#   'Burtnieku',
#   'Burtnieku',
#   'Burtnieku',
#   'Burtnieku',
#   'Burtnieku',
#   'Burtnieku',
#   'Burtnieku',
#   'Carnikavas',
#   'Carnikavas',
#   'Carnikavas',
#   'Carnikavas',
#   'Carnikavas',
#   'Carnikavas',
#   'Carnikavas',
#   'Carnikavas',
#   'Carnikavas',
#   'Carnikavas',
#   'Carnikavas',
#   'Cesu',
#   'Cesu',
#   'Cesu',
#   'Cesu',
#   'Cesu',
#   'Cesu',
#   'Cesu',
#   'Cesvaines',
#   'Cesvaines',
#   'Cesvaines',
#   'Cesvaines',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Ciblas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   'Dagdas',
#   ...],
#  ['ILkene',
#   'Kadaga',
#   'ani',
#   'ani',
#   'Garkalne',
#   'adazi',
#   'Alderi',
#   'Atari',
#   'Baltezers',
#   'Birznieki',
#   'Divezeri',
#   'Eimuri',
#   'Garkalne',
#   'Kadaga',
#   'Staprini',
#   'Aglona',
#   'Aglonas Madelani',
#   'Akatnieki',
#   'ALhovka',
#   'Ancverini 1',
#   'Ancverini 2',
#   'Atskiras Madelani',
#   'Beki',
#   'Berzgale',
#   'Besoni',
#   'Botori',
#   'Bruveri',
#   'Cecerski',
#   'CegeLna',
#   'cuhnani',
#   'Dimperi',
#   'Dudiski',
#   'Dzervanki',
#   'Ezera Ukini',
#   'Fintmuiza',
#   'Gorodoka',
#   'GuLbinka',
#   'Guteni',
#   'Janova',
#   'Jaudzemi',
#   'Jaunaglona',
#   'JaunsekLi',
#   'Jonani',
#   'Kapini',
#   'Kapinu RuskuLi',
#   'KavaLi',
#   'Kazimirovka',
#   'Kodori',
#   'Krivoseji',
#   'Kukari',
#   'Kundziniski',
#   'Leitani',
#   'Lielie Bernani',
#   'Lielie DzerkaLi',
#   'Livdani',
#   'Livdaniski',
#   'Lopoti',
#   'Luckini',
#   'Marjanova',
#   'Matisani',
#   'Mazie Bernani',
#   'Mazie DzerkaLi',
#   'MeiruLi',
#   'Meza Dauksti',
#   'Meza Ukini',
#   'Misani',
#   'Novinki',
#   'Ostrova',
#   'Otoriski',
#   'Peski',
#   'Puzaniski',
#   'Rajecki',
#   'Repsi',
#   'Rivari',
#   'Rivariski',
#   'Rotka',
#   'RuskuLi',
#   'Ruskuliski',
#   'RutuLi',
#   'Rutuliski',
#   'Salenieki',
#   'SekLa Dauksti',
#   'SekLi',
#   'Sgajevski',
#   'Sienapurvs',
#   'Sila Dauksti',
#   'Skudru Grebezi',
#   'Skujas',
#   'Smani',
#   'Spiki',
#   'Starodvorje',
#   'Staskuni',
#   'sumski',
#   'Terehova',
#   'TuLi',
#   'Valaini',
#   'VoguLi',
#   'Zaikovscina',
#   'Zlotniski',
#   'Zukuli',
#   'Aksenova',
#   'Ancani',
#   'Barsevski',
#   'Boreksti',
#   'Borovije',
#   'Briveri',
#   'CesLava',
#   'FoLvaroka',
#   'ILjuhina',
#   'Jaudzemi',
#   'Kalna Kudini',
#   'Karaseva',
#   'Kastjuki',
#   'Kazuliski',
#   'Klovini',
#   'KrekeLi',
#   'Krivini',
#   'Krizovka',
#   'Lejas Kudini',
#   'Malajoniki',
#   'Marhilevici',
#   'Maslabojeva',
#   'Melderi',
#   'Mihailina',
#   'Nikucki',
#   'Peipini',
#   'Pildigi',
#   'Podskoceva',
#   'Prusaki',
#   'Putani',
#   'Rumaki',
#   'sahmani',
#   'Sampani',
#   'Sarguni',
#   'skeltova',
#   'skerbiski',
#   'Slostovka',
#   'Staskevici',
#   'Suhailina',
#   'Suveizdi',
#   'Upes Kudini',
#   'Zabalotki',
#   'Zukuli',
#   'Akmenica',
#   'Apsenieki',
#   'Belogrudova',
#   'Grabavscizna',
#   'Graveri',
#   'KLisova',
#   'KovaLova',
#   'Kropiski',
#   'Lipski',
#   'Luni',
#   'MateLi',
#   'Melenki',
#   'Mickevici',
#   'Ostrovs',
#   'Pizani',
#   'RageLi',
#   'Raginski',
#   'Sakova',
#   'Savicki',
#   'Sloboda',
#   'SpaLbi',
#   'Timofejevka',
#   'Trupi',
#   'Voveri',
#   'Barovka',
#   'Blazevici',
#   'Deneva',
#   'DubuLi',
#   'Dunski',
#   'FoLvarka',
#   'Geranimova',
#   'Guta',
#   'Hmilovka',
#   'Jegorova',
#   'Kalna Butkani',
#   'Karelova',
#   'KastuLina',
#   'KauskaLi',
#   'Konovalova',
#   'Koskina',
#   'Kruciniski',
#   'Leitaniski',
#   'Lejas Butkani',
#   'Leonovici',
#   'Lesinski',
#   'Makusi',
#   'Musa',
#   'nikitiski',
#   'Novinki',
#   'Novosjolki',
#   'Ogurecka',
#   'Priezmale',
#   'Pustoski',
#   'Reiniki',
#   'ReLenki',
#   'Ribacki',
#   'Rovini',
#   'Siliski',
#   'Sirotka',
#   'Sopuski',
#   'Stanoviski',
#   'Ubogova',
#   'Vortniki',
#   'Zahariski',
#   'Zilais Akmens',
#   'Jaunokra',
#   'Kumalani',
#   'Ladiskina',
#   'Muranciki',
#   'Protiriha',
#   'Ratniki',
#   'Aizkraukle',
#   'Aizkraukles stacija',
#   'Kalvenes',
#   'Kalvene',
#   'Kalvenes stacija',
#   'Cirava',
#   'Dzervenieki',
#   'Apriki',
#   'Bojas',
#   'Kudra',
#   'Padure',
#   'Rokaizi',
#   'Rokasbirze',
#   'stakeldanga',
#   'Tebras',
#   'Kazdanga',
#   'Aknistes',
#   'Ancene',
#   'Asare',
#   'Garsene',
#   'Kraujas',
#   'Staiceles',
#   'Ozolmuiza',
#   'Puikule',
#   'Puikules stacija',
#   'Ungurpils',
#   'Braslava',
#   'Vilzeni',
#   'Almale',
#   'Alsunga',
#   'Aizupites',
#   'Marinkalns',
#   'Ziemeri',
#   'Alsviki',
#   'Pullans',
#   'Strautini',
#   'Korneti',
#   'Jaunlaicene',
#   'Jaunanna',
#   'Anna',
#   'Kalncempji',
#   'Jaunzemi',
#   'Zeltini',
#   'Beja',
#   'Kolbergis',
#   'Markalne',
#   'Pededze',
#   'Liepna',
#   'Malupe',
#   'Sofikalns',
#   'Brenci',
#   'Amata',
#   'Drabesi',
#   'Livi',
#   'Meijermuiza',
#   'Nitaure',
#   'Annas',
#   'Berzs',
#   'Kligene',
#   'Zaube',
#   'Bille',
#   'Ieriki',
#   'KarLi',
#   'Spare',
#   'giksi',
#   'Sermuksi',
#   'Skujene',
#   'Apes',
#   'Gaujiena',
#   'Trapene',
#   'Vidaga',
#   'Viresi',
#   'Vecauce',
#   'Vitini',
#   'Bene',
#   'VecmikeLi',
#   'Snikere',
#   'ile',
#   'kevele',
#   'kiegeLceplis',
#   'Lielauce',
#   'Razotaji',
#   'Ukri',
#   'Kudra',
#   'Pavasari',
#   'Babite',
#   'Mezares',
#   'Priezciems',
#   'Sebruciems',
#   'Spilve',
#   'Gatciems',
#   'Pernciems',
#   'Silmalas',
#   'Sipolciems',
#   'Spunciems',
#   'Straupciems',
#   'VarkaLi',
#   'Brivkalni',
#   'Cielavas',
#   'Dzerves',
#   'Dzilnuciems',
#   'EgLuciems',
#   'Kagi',
#   'Klives',
#   'Lapsas',
#   'Liberi',
#   'Pinki',
#   'Pluguciems',
#   'Priezciems',
#   'Sebruciems',
#   'Skarduciems',
#   'Trenci',
#   'VikuLi',
#   'Sunupes',
#   'Varpas',
#   'Apsova',
#   'Bahmati',
#   'Baltinava',
#   'Barzulova',
#   'Blauzgova',
#   'Boncani',
#   'Brieksine',
#   'Buksti',
#   'cudarine',
#   'Danski',
#   'Demerova',
#   'Dokti',
#   'Dupurova',
#   'Durspride',
#   'Dziervine',
#   'Ezerova',
#   'Gnilki',
#   'Grikovka',
#   'Jorzova',
#   'Karpova',
#   'Kasi',
#   'Keisi',
#   'kevesdruva',
#   'KLangova',
#   'Kolnumezi',
#   'Kotlova',
#   'Kozurki',
#   'KraukLova',
#   'Kuznecova',
#   'Lauruti',
#   'Leidumi',
#   'Lemesova',
#   'Levaskova',
#   'Macusola',
#   'MaiLupe',
#   'Merkuzine',
#   'Mezupe',
#   'Misani',
#   'Morkova',
#   'Motrine',
#   'ObeLova',
#   'Odumova',
#   'Pazlauga',
#   'Peisova',
#   'Pleitova',
#   'Pliesova',
#   'PuncuLova',
#   'Punduri',
#   'Putrova',
#   'Risova',
#   'Rudukova',
#   'Safronovka',
#   'Sarkani',
#   'SilagaiLi',
#   'Sloboda',
#   'Slostova',
#   'Surikova',
#   'Svatune',
#   'SviLpova',
#   'Telezniki',
#   'Timsani',
#   'Tutinova',
#   'Upini',
#   'Upmale',
#   'uzulova',
#   'Vasiliski',
#   'Viborgi',
#   'ViLumi',
#   'zeikari',
#   'Zubki',
#   'Centramuiza',
#   'Deksni',
#   'DubLava',
#   'Guznava',
#   'Krasnogorka',
#   'Lazdukalns',
#   'Lemesava',
#   'Lemesava',
#   'Pelnupe',
#   'Perkoni',
#   'RezgaLi',
#   'Salmani',
#   'Silakrogs',
#   'Stekintava',
#   'Stepjugabali',
#   'sucene',
#   'Tutinava',
#   'Vanki',
#   'Vejava',
#   'VerpuLeva',
#   'Zaci',
#   'zaugupe',
#   'azudambis',
#   'Dobenieki',
#   'Durupe',
#   'Dzenulauza',
#   'Karklinieki',
#   'Keni',
#   'Lacugabali',
#   'Lacupe',
#   'Meki',
#   'Naudaskalns',
#   'Ozolsala',
#   'Pilskalns',
#   'Plitinava',
#   'Ravusala',
#   'Reci',
#   'Silamala',
#   'Auska',
#   'Doburucis',
#   'Gruznis',
#   'Sudarbe',
#   'Vilkarucis',
#   'Vuskusala',
#   'Balvu stacija',
#   'Briedisi',
#   'Celmene',
#   'Celmenieki',
#   'Druvenieki',
#   'Dvorupe',
#   'Esmeraldova',
#   'Ezusala',
#   'Fabrika',
#   'Gobusala',
#   'Grivgals',
#   'Janusala',
#   'Kozlova',
#   'Kurna',
#   'Lasinnaja',
#   'Lidumnieki',
#   'Liepava',
#   'Meirani',
#   'Nikolajeva',
#   'OLgina',
#   'Paulani',
#   'Pordari',
#   'Robeznieki',
#   'Silaciems',
#   'Sita',
#   'Stirnusala',
#   'TireLi',
#   'Tropini',
#   'VasiLjeva',
#   'Vladimirova',
#   'Augstasils',
#   'Bilga',
#   'Brieksine',
#   'Briezusala',
#   'Cerpene',
#   'cilipine',
#   'DubLeva',
#   'Jaunzemes',
#   'Kroni',
#   'Krucinova',
#   'Lazduleja',
#   'Ploskene',
#   'PusLeva',
#   'Puzulova',
#   'Sepovka',
#   'Vazovka',
#   'Gailisi',
#   'Dambisi',
#   'Krutova',
#   'Lutenani',
#   'Ranguci',
#   'Savani',
#   'Upenieki',
#   'Vectilza',
#   'Akmenruci',
#   'Baltini',
#   'Barbani',
#   'Degumnieki',
#   'Dievzeikari',
#   'Eglisi',
#   'Jaujas',
#   'Kadiseva',
#   'Kapessils',
#   'Keibinieki',
#   'KLavusala',
#   'Kugenieki',
#   'Menesi',
#   'Mezarijas',
#   'Petrovka',
#   'Raicene',
#   'Robeznieki',
#   'RoditeLi',
#   'Rutkova',
#   'Silini',
#   'Siltene',
#   'Spirgi',
#   'Stangas',
#   'Tilza',
#   'Toki',
#   'udrene',
#   'Vindava',
#   'Zvaigznes',
#   'Mezupe',
#   'Purvinas',
#   'Vitoli',
#   'Zeltupe',
#   'Krampinas',
#   'Krisjani',
#   'Naglisi',
#   'Putrani',
#   'Runcene',
#   'Vaksenieki',
#   'zogi',
#   'Apsenieki',
#   'Augstari',
#   'BeLauski',
#   'Berzi',
#   'Berziesi',
#   'Berzpils',
#   'Bonifacova',
#   'Domopole',
#   'Gabrani',
#   'Golvari',
#   'Gribkova',
#   'Jabalova',
#   'Javenieki',
#   'Kazoki',
#   'KiLauka',
#   'KLavini',
#   'Kononi',
#   'Lacaunieki',
#   'Lauskinieki',
#   'Lidumnieki',
#   'Masalnieki',
#   'Muramuiza',
#   'Osudari',
#   'Palini',
#   'Pelerijas',
#   'Pugaci',
#   'Saksmale',
#   'Silamuiza',
#   'Sola',
#   'Somi',
#   'Sprodzenieki',
#   'Tabakova',
#   'Vecpils',
#   'ViskuLi',
#   'Zosuli',
#   'Zvonovka',
#   'Aizezere',
#   'Annasbirzs',
#   'Apsukalns',
#   'Augstabirzs',
#   'Bereznaks',
#   'cagas',
#   'Dampadruva',
#   'Derdzini',
#   'EgLukalns',
#   'Georgijeva',
#   'Judini',
#   'Kacupe',
#   'Kuprava',
#   'Lauzas',
#   'Mezarija',
#   'Miezaji',
#   'Oknupe',
#   'Pakalniesi',
#   'PokuLeva',
#   'Rimsi',
#   'Smiltene',
#   'Sprogas',
#   'Valentinova',
#   'Viksna',
#   'ZaLmeznieki',
#   'Asusils',
#   'Dubudeksnis',
#   'Kuprava',
#   'Maksinava',
#   'Maksinava Strauti',
#   'Repseva',
#   'Strauti',
#   'Babani',
#   'Berzkalne',
#   'Bruklaji',
#   'Karnite',
#   'Krievkalns',
#   'Lielmeznieki',
#   'Ploskena',
#   'Taureskalns',
#   'Uzgova',
#   'Aizpurve',
#   'Auzaji',
#   'Briezeva',
#   'Burceva',
#   'Elksneva',
#   'Mezarija',
#   'Mozinki',
#   'Murava',
#   'Rubeni',
#   'Vistusala',
#   'Aizupe',
#   'Akmensala',
#   'Aviksi',
#   'Brinkene',
#   'Burtnieki',
#   'Ciganova',
#   'Dmitrijevka',
#   'DukuLeva',
#   'EgLeva',
#   'EgLuciems',
#   'Griva',
#   'KiLi',
#   'Lozdova',
#   'Lukjanovka',
#   'Malnusala',
#   'Medvezevka',
#   'Mezalauki',
#   'Mezareja',
#   'Orlova',
#   'Osinovka',
#   'Ozolova',
#   'Ozolziles',
#   'Petrovka',
#   'Plesova',
#   'Priedes',
#   'Purlova',
#   'sceglova',
#   'Spickova',
#   'Stigas',
#   'sumkova',
#   'Zaikova',
#   'Zirgadobe',
#   'Zobukalns',
#   'Abrinas',
#   'Ausala',
#   'Begunova',
#   'Belini',
#   'Bokova',
#   'Briezuciems',
#   'Dambergi',
#   'Denicova',
#   'DukuLeva',
#   'GrusLeva',
#   'Kvasneva',
#   'Ostrolidumi',
#   'stikunova',
#   'Stouberova',
#   'Torkova',
#   'Berzkalni',
#   'Elektriki',
#   'Guntas',
#   'Janeikas',
#   'Jauncode',
#   'Jumprava',
#   'Musa',
#   'Ritausmas',
#   'Brunava',
#   'Budberga',
#   'ergLi',
#   'Grenctale',
#   'Ceraukste',
#   'Code',
#   'Dalini',
#   'Lambarte',
#   'adzuni',
#   'Berzi',
#   'Pastaliski',
#   'Jaunsaule',
#   'Ceplis',
#   'Mezotne',
#   'Garoza',
#   'Strelnieki',
#   'Davini',
#   'BirzgaLi',
#   'Brunaviski',
#   'Bukubirzs',
#   'KrievgaLi',
#   'Musa',
#   'Pace',
#   'Pamusa',
#   'Piragi',
#   'Pogranica',
#   'Uzvara',
#   'Likverteni',
#   'Vecsaule',
#   'Zvaigzne',
#   'Kudra',
#   'Ozolaine',
#   'Kauguri',
#   'Kaugurmuiza',
#   'Lici',
#   'Murmuiza',
#   'BrenguLi',
#   'Cempi',
#   'Trikata',
#   'udrinas',
#   'Emburga',
#   'Kalnsetas',
#   'Lielciecere',
#   'Oskalni',
#   'Blidene',
#   'Pilsblidene',
#   'Sturi',
#   'Remte',
#   'Gaiki',
#   'Lielsatiki',
#   'Satiki',
#   'Vecgaiki',
#   'Burtnieki',
#   'Matisi',
#   'Vecate',
#   'Pilati',
#   'Rupnieki',
#   'Valmiermuiza',
#   'Lizdeni',
#   'Renceni',
#   'Daksti',
#   'evele',
#   'Carnikava',
#   'Eimuri',
#   'Garciems',
#   'Garupe',
#   'Gauja',
#   'Kalngale',
#   'Laveri',
#   'Lilaste',
#   'Mezciems',
#   'Mezgarciems',
#   'SiguLi',
#   'Cesis',
#   'Cesis',
#   'Krivi',
#   'MezmaLi',
#   'RamuLi',
#   'Ridzene',
#   'Veismani',
#   'Grasi',
#   'Karkli',
#   'Karzdaba',
#   'KraukLi',
#   'Blonti',
#   'Bubini',
#   'Cabuli',
#   'codarani',
#   'DegLova',
#   'Dubrovka',
#   'Gutki',
#   'IerzeLova',
#   'Jakuci',
#   'Kreici',
#   'Liela Medisova',
#   'Maza Medisova',
#   'Morozovka',
#   'Ozorgi',
#   'Plaudisi',
#   'SilagaiLi',
#   'skinci',
#   'SkradeLi',
#   'TeLakolni',
#   'Vilceni',
#   'Vonogi',
#   'Balalaiki',
#   'Cibla',
#   'Degteri',
#   'Eversmuiza',
#   'Felicianova',
#   'Jurani',
#   'Kondrati',
#   'Kozlovski',
#   'Lielie Truksani',
#   'Meza Kocki',
#   'Morozovka',
#   'Peksova',
#   'Spegi',
#   'Stocinova',
#   'Tridna',
#   'Tumova',
#   'Voiti',
#   'Voloji',
#   'Zeltini',
#   'Barisi',
#   'Greci',
#   'KaLvisi',
#   'Lopsti',
#   'Marenpole',
#   'Mjaisi',
#   'Ozupiene',
#   'PuncuLi',
#   'scastLivi',
#   'Skrini',
#   'Sokani',
#   'udeni',
#   'Vacumnieki',
#   'Akasi',
#   'armani',
#   'Astenci',
#   'Babrova',
#   'BartuLi',
#   'Berozovka',
#   'civzuLi',
#   'ciziki',
#   'Dolgoseji',
#   'HmeLnecki',
#   'Jasenci',
#   'Jaski',
#   'Joski',
#   'KLesniki',
#   'Kozusola',
#   'Krivanda',
#   'Kujerci',
#   'Kurjanova',
#   'Kusneri',
#   'Lidumnieki',
#   'Liepu Sala',
#   'Petruconki',
#   'Platpirova',
#   'Recnaja',
#   'Rudusi',
#   'Seimani',
#   'skinci',
#   'snitniki',
#   'Spirki',
#   'Vacu Kalni',
#   'Avisi',
#   'cigani',
#   'Fedcenki',
#   'Gornie',
#   'Iudri',
#   'Kaziniki',
#   'Lahi',
#   'Latisi',
#   'MasLenki',
#   'Merdzine',
#   'Mezerniki',
#   'Nuraugi',
#   'Obscina',
#   'PerekLi',
#   'PoLaki',
#   'Potasi',
#   'Poznakova',
#   'Pusmucova',
#   'saraki',
#   'Sipki',
#   'skinci',
#   'SLapnie',
#   'smati',
#   'SnotiuLi',
#   'Staupine',
#   'Steponi',
#   'Tereki',
#   'Vacumniki',
#   'Valujeva',
#   'Vornaisi',
#   'Zujova',
#   'Banoneja',
#   'Bierziniki',
#   'Binova',
#   'Bleivi',
#   'Boluzova',
#   'DiunokLi',
#   'Ezersala',
#   'Franapole',
#   'JaunzeLci',
#   'Jaunzogoti',
#   'KaLvi',
#   'Kitkova',
#   'Kiuti',
#   'KLovi',
#   'Kristuzani',
#   'Kriveni',
#   'Kusnerova',
#   'Lauci',
#   'Lielie Litauniki',
#   'Lucmuiza',
#   'Mazie Litauniki',
#   'Mazie Truksani',
#   'Miltukolni',
#   'Mjakinki',
#   'Muiziniki',
#   'ObuLniki',
#   'Orehova',
#   'Petriki',
#   'PikstuLi',
#   'Pudukolni',
#   'Razanova',
#   'Rubezniki',
#   'Rudzeisi',
#   'salupinki',
#   'SeLekova',
#   'spegi',
#   'Teiruma Kocki',
#   'TeLakolni',
#   'udeni',
#   'Ustja',
#   'uticova',
#   'Vaczogoti',
#   'Vasarani',
#   'Veserova',
#   'Vierni',
#   'Virpi',
#   'Zitiski',
#   'Zuzeisi',
#   'Zvirgzdene',
#   'Alzenova',
#   'Beitani',
#   'Bojari',
#   'Dagdas Muiza',
#   'JubeLi',
#   'Mazie Rapsi',
#   'Midisi',
#   'Neikuri',
#   'Ozolini',
#   'Plotki',
#   'PurpLi',
#   'Rabsi',
#   'Rumpisi',
#   'Sloboda',
#   'Ustje',
#   'Vecdome',
#   'Zabari',
#   'ZeLLi',
#   'Aprobavci',
#   'Asune',
#   'Butkoni',
#   'Dzirvaniski',
#   'Ferma',
#   'FoLvaroka',
#   'KaraLova',
#   'Klabauci',
#   'KovaLki',
#   'Kozlova',
#   'Krinica',
#   'KurLinova',
#   'Lutavci',
#   'Maza Asune',
#   'Maza Jolza',
#   'Mazie Zeizi',
#   'Mengi',
#   'Paukstova',
#   'PLupova',
#   'Raceva',
#   'Reini',
#   'Tilesova',
#   'Zeliski',
#   'Zukulova',
#   'ApaLi',
#   'Barinauci',
#   'Blusova',
#   'Dinaborciki',
#   'Katriniski',
#   'kepova',
#   'Kulakova',
#   'Luksova',
#   'Madalani',
#   'Mazie ApaLi',
#   'MeLkeri',
#   'Neiksani',
#   'PLesneva',
#   'Posova',
#   'Sumkova',
#   'Tukisi',
#   'Vorzova',
#   'Aleksandrova',
#   'Avlasenki',
#   'Bogdani',
#   'Bronki',
#   'Eisaki',
#   'Ignatova',
#   'Konstantinova',
#   'Kromani',
#   'KubuLniski',
#   'Lemesi',
#   'Lozdi',
#   'Magnusova',
#   'Nartisi',
#   'Noviki',
#   'Ojatnieki',
#   ...]]

# %%
df = pd.DataFrame({
    'state': states,
    'city': city,
    'zipcode': zipcode
})
df.set_index('state', inplace = True)
df.sort_index(inplace = True)
df.drop_duplicates(keep="first", inplace = True)
df
# Out:
#              city  zipcode
# state
# Adazu      ILkene  LV-2103
# Adazu      Kadaga  LV-2103
# Adazu         ani  LV-2136
# Adazu         ani  LV-2137
# Adazu    Garkalne  LV-2137
# ...           ...      ...
# Zilupes   SviLova  LV-5751
# Zilupes  Terehova  LV-5751
# Zilupes    Troski  LV-5751
# Zilupes      ZiLi  LV-5751
# Zilupes    zizeva  LV-5751
#
# [6063 rows x 2 columns]

# %%
df.to_csv("Latvia.csv")
